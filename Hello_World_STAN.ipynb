# %%
import stan
import pandas as pd
import numpy as np
import scipy.stats as stats 
import matplotlib.pyplot as plt
# this is a work around needed to run pystan in some machines
import nest_asyncio
nest_asyncio.apply()
# Out:
# /home/grimm/anaconda3/envs/BML4SR/lib/python3.10/site-packages/stan/plugins.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %% [markdown]
# ### Create fake data

# %%
mu = 5
sigma = 3
np.random.seed(0)
data = np.random.normal(mu,sigma,200)

# %% [markdown]
# ### STAN model

# %%
my_model = """
data {
 int <lower=0> N; // length of data
 vector[N] measurements; // data
}

parameters {
  real mu;
  real<lower=0> sigma;
}

model {
  mu ~ normal(0,10);   // define prior for mu (not needed, but prior info is always good)
  sigma ~ cauchy(0,1);  // define prior for sigma (idem)
  for (n in 1:N) {
  measurements[n] ~ normal(mu, sigma);  
}
}
"""

# %% [markdown]
# ### Infer

# %%
my_data = {'N': len(data), 'measurements': data }

# %%
model = stan.build(my_model, data=my_data, random_seed=10);
# Out:
# Building...
# In Datei, eingebunden von /home/grimm/anaconda3/envs/BML4SR/lib/python3.10/site-packages/httpstan/include/tbb/concurrent_unordered_map.h:26,
#                  von /home/grimm/anaconda3/envs/BML4SR/lib/python3.10/site-packages/httpstan/include/stan/math/rev/core/profiling.hpp:10,
#                  von /home/grimm/anaconda3/envs/BML4SR/lib/python3.10/site-packages/httpstan/include/stan/math/rev/core.hpp:53,
#                  von /home/grimm/anaconda3/envs/BML4SR/lib/python3.10/site-packages/httpstan/include/stan/math/rev.hpp:10,
#                  von /home/grimm/anaconda3/envs/BML4SR/lib/python3.10/site-packages/httpstan/include/stan/math.hpp:19,
#                  von /home/grimm/anaconda3/envs/BML4SR/lib/python3.10/site-packages/httpstan/include/stan/model/model_header.hpp:4,
#                  von /home/grimm/.cache/httpstan/4.13.0/models/6hewe2jy/model_6hewe2jy.cpp:2:
# /home/grimm/anaconda3/envs/BML4SR/lib/python3.10/site-packages/httpstan/include/tbb/internal/_concurrent_unordered_impl.h: In Instanziierung von »void tbb::interface5::internal::concurrent_unordered_base<Traits>::internal_init() [with Traits = tbb::interface5::concurrent_unordered_map_traits<std::pair<std::basic_string<char>, std::thread::id>, stan::math::profile_info, tbb::interface5::internal::hash_compare<std::pair<std::basic_string<char>, std::thread::id>, stan::math::internal::hash_profile_key, stan::math::internal::equal_profile_key>, tbb::tbb_allocator<std::pair<const std::pair<std::basic_string<char>, std::thread::id>, stan::math::profile_info> >, false>]«:
# /home/grimm/anaconda3/envs/BML4SR/lib/python3.10/site-packages/httpstan/include/tbb/internal/_concurrent_unordered_impl.h:773:9:   erfordert durch »tbb::interface5::internal::concurrent_unordered_base<Traits>::concurrent_unordered_base(tbb::interface5::internal::concurrent_unordered_base<Traits>::size_type, const hash_compare&, const allocator_type&) [with Traits = tbb::interface5::concurrent_unordered_map_traits<std::pair<std::basic_string<char>, std::thread::id>, stan::math::profile_info, tbb::interface5::internal::hash_compare<std::pair<std::basic_string<char>, std::thread::id>, stan::math::internal::hash_profile_key, stan::math::internal::equal_profile_key>, tbb::tbb_allocator<std::pair<const std::pair<std::basic_string<char>, std::thread::id>, stan::math::profile_info> >, false>; tbb::interface5::internal::concurrent_unordered_base<Traits>::size_type = long unsigned int; tbb::interface5::internal::concurrent_unordered_base<Traits>::hash_compare = tbb::interface5::internal::hash_compare<std::pair<std::basic_string<char>, std::thread::id>, stan::math::internal::hash_profile_key, stan::math::internal::equal_profile_key>; tbb::interface5::internal::concurrent_unordered_base<Traits>::allocator_type = std::allocator_traits<tbb::tbb_allocator<std::pair<const std::pair<std::basic_string<char>, std::thread::id>, stan::math::profile_info> > >::rebind_alloc<std::pair<const std::pair<std::basic_string<char>, std::thread::id>, stan::math::profile_info> >]«
# /home/grimm/anaconda3/envs/BML4SR/lib/python3.10/site-packages/httpstan/include/tbb/concurrent_unordered_map.h:112:68:   erfordert durch »tbb::interface5::concurrent_unordered_map<Key, T, Hasher, Key_equality, Allocator>::concurrent_unordered_map(tbb::interface5::concurrent_unordered_map<Key, T, Hasher, Key_equality, Allocator>::size_type, const hasher&, const key_equal&, const allocator_type&) [with Key = std::pair<std::basic_string<char>, std::thread::id>; T = stan::math::profile_info; Hasher = stan::math::internal::hash_profile_key; Key_equality = stan::math::internal::equal_profile_key; Allocator = tbb::tbb_allocator<std::pair<const std::pair<std::basic_string<char>, std::thread::id>, stan::math::profile_info> >; tbb::interface5::concurrent_unordered_map<Key, T, Hasher, Key_equality, Allocator>::size_type = long unsigned int; tbb::interface5::concurrent_unordered_map<Key, T, Hasher, Key_equality, Allocator>::hasher = stan::math::internal::hash_profile_key; tbb::interface5::concurrent_unordered_map<Key, T, Hasher, Key_equality, Allocator>::key_equal = stan::math::internal::equal_profile_key; tbb::interface5::concurrent_unordered_map<Key, T, Hasher, Key_equality, Allocator>::allocator_type = std::allocator_traits<tbb::tbb_allocator<std::pair<const std::pair<std::basic_string<char>, std::thread::id>, stan::math::profile_info> > >::rebind_alloc<std::pair<const std::pair<std::basic_string<char>, std::thread::id>, stan::math::profile_info> >]«
# /home/grimm/.cache/httpstan/4.13.0/models/6hewe2jy/model_6hewe2jy.cpp:6:25:   von hier erfordert
# /home/grimm/anaconda3/envs/BML4SR/lib/python3.10/site-packages/httpstan/include/tbb/internal/_concurrent_unordered_impl.h:1345:15: Warnung: »void* memset(void*, int, size_t)« Säubern eines Objekts des Typs »struct tbb::atomic<tbb::interface5::internal::flist_iterator<tbb::interface5::internal::split_ordered_list<std::pair<const std::pair<std::basic_string<char>, std::thread::id>, stan::math::profile_info>, tbb::tbb_allocator<std::pair<const std::pair<std::basic_string<char>, std::thread::id>, stan::math::profile_info> > >, std::pair<const std::pair<std::basic_string<char>, std::thread::id>, stan::math::profile_info> >*>« ohne triviale Kopierzuweisung; use assignment or value-initialization instead [-Wclass-memaccess]
#  1345 |         memset(my_buckets, 0, sizeof(my_buckets));
#       |         ~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# In Datei, eingebunden von /home/grimm/anaconda3/envs/BML4SR/lib/python3.10/site-packages/httpstan/include/tbb/tbb_profiling.h:123,
#                  von /home/grimm/anaconda3/envs/BML4SR/lib/python3.10/site-packages/httpstan/include/tbb/task.h:36,
#                  von /home/grimm/anaconda3/envs/BML4SR/lib/python3.10/site-packages/httpstan/include/tbb/task_arena.h:23,
#                  von /home/grimm/anaconda3/envs/BML4SR/lib/python3.10/site-packages/httpstan/include/stan/math/prim/core/init_threadpool_tbb.hpp:18,
#                  von /home/grimm/anaconda3/envs/BML4SR/lib/python3.10/site-packages/httpstan/include/stan/math/prim/core.hpp:4,
#                  von /home/grimm/anaconda3/envs/BML4SR/lib/python3.10/site-packages/httpstan/include/stan/math/rev/core/Eigen_NumTraits.hpp:5,
#                  von /home/grimm/anaconda3/envs/BML4SR/lib/python3.10/site-packages/httpstan/include/stan/math/rev/core/typedefs.hpp:7,
#                  von /home/grimm/anaconda3/envs/BML4SR/lib/python3.10/site-packages/httpstan/include/stan/math/rev/core/chainable_object.hpp:6,
#                  von /home/grimm/anaconda3/envs/BML4SR/lib/python3.10/site-packages/httpstan/include/stan/math/rev/core.hpp:10,
#                  von /home/grimm/anaconda3/envs/BML4SR/lib/python3.10/site-packages/httpstan/include/stan/math/rev.hpp:10,
#                  von /home/grimm/anaconda3/envs/BML4SR/lib/python3.10/site-packages/httpstan/include/stan/math.hpp:19,
#                  von /home/grimm/anaconda3/envs/BML4SR/lib/python3.10/site-packages/httpstan/include/stan/model/model_header.hpp:4,
#                  von /home/grimm/.cache/httpstan/4.13.0/models/6hewe2jy/model_6hewe2jy.cpp:2:
# /home/grimm/anaconda3/envs/BML4SR/lib/python3.10/site-packages/httpstan/include/tbb/atomic.h:507:1: Anmerkung: »struct tbb::atomic<tbb::interface5::internal::flist_iterator<tbb::interface5::internal::split_ordered_list<std::pair<const std::pair<std::basic_string<char>, std::thread::id>, stan::math::profile_info>, tbb::tbb_allocator<std::pair<const std::pair<std::basic_string<char>, std::thread::id>, stan::math::profile_info> > >, std::pair<const std::pair<std::basic_string<char>, std::thread::id>, stan::math::profile_info> >*>« wird hier deklariert
#   507 | atomic<T*>: internal::atomic_impl_with_arithmetic<T*,ptrdiff_t,T> {
#       | ^~~~~~~~~~
# Building: 14.7s, done.

# %%
fit = model.sample(num_chains=4, num_samples=1000)
# Out:
# Sampling:   0%
# Sampling:  25% (2000/8000)
# Sampling:  50% (4000/8000)
# Sampling:  75% (6000/8000)
# Sampling: 100% (8000/8000)
# Sampling: 100% (8000/8000), done.
# Messages received during sampling:
#   Gradient evaluation took 7e-05 seconds
#   1000 transitions using 10 leapfrog steps per transition would take 0.7 seconds.
#   Adjust your expectations accordingly!
#   Gradient evaluation took 4.4e-05 seconds
#   1000 transitions using 10 leapfrog steps per transition would take 0.44 seconds.
#   Adjust your expectations accordingly!
#   Gradient evaluation took 4.9e-05 seconds
#   1000 transitions using 10 leapfrog steps per transition would take 0.49 seconds.
#   Adjust your expectations accordingly!
#   Gradient evaluation took 4.4e-05 seconds
#   1000 transitions using 10 leapfrog steps per transition would take 0.44 seconds.
#   Adjust your expectations accordingly!

# %% [markdown]
# ### Assessment

# %%
df = fit.to_frame() 
df
# Out:
# parameters        lp__  accept_stat__  stepsize__  treedepth__  n_leapfrog__  \
# draws
# 0          -325.637334       0.862713    0.810680          1.0           3.0
# 1          -325.400525       0.983008    0.865229          1.0           3.0
# 2          -326.946710       0.919872    0.820448          3.0           7.0
# 3          -325.681164       1.000000    0.961095          2.0           3.0
# 4          -325.558798       0.997388    0.810680          2.0           3.0
# ...                ...            ...         ...          ...           ...
# 3995       -327.249999       1.000000    0.961095          2.0           7.0
# 3996       -326.969203       0.792725    0.810680          3.0           7.0
# 3997       -326.301699       0.996904    0.865229          2.0           3.0
# 3998       -325.454293       0.959753    0.820448          2.0           3.0
# 3999       -325.744984       0.980585    0.961095          2.0           3.0
#
# parameters  divergent__    energy__        mu     sigma
# draws
# 0                   0.0  327.454687  5.308812  2.962025
# 1                   0.0  326.415081  5.246533  3.115726
# 2                   0.0  330.651773  5.078527  2.818869
# 3                   0.0  325.746244  5.037253  3.018539
# 4                   0.0  325.815861  5.186868  3.165885
# ...                 ...         ...       ...       ...
# 3995                0.0  328.630983  4.896449  3.290092
# 3996                0.0  329.242315  5.339431  2.816257
# 3997                0.0  326.575919  5.494617  2.996659
# 3998                0.0  326.239550  5.318788  3.037761
# 3999                0.0  327.604266  5.315523  3.183803
#
# [4000 rows x 9 columns]

# %%
plt.hist(df['mu'], color='blue',  histtype='step', density=1, label='$\mu$ posterior')
plt.hist(df['sigma'], color='red', histtype='step', density=1, label='$\sigma$ posterior')
plt.axvline(mu, color='blue', linestyle='dashed', label='$\mu$ true')
plt.axvline(sigma, color='red', linestyle='dashed', label='$\sigma$ true')
plt.ylabel('Probability density')
plt.legend()
plt.show()

# %%
x = np.linspace(-3,13)
plt.hist(data, color='magenta',  histtype='step', density=1, label='Real data')
plt.axvline(mu, color='blue', linestyle='dashed', label='$\mu$ true')
#plt.plot(x, stats.norm.pdf(x, np.mean(df['mu']), np.mean(df['sigma'])), color='magenta', linestyle='dashed', label='Distribution using means for each parameter')
for i in range(200):
    if i==0: plt.plot(x, stats.norm.pdf(x, np.mean(df.iloc[i]['mu']), np.mean(df.iloc[i]['sigma'])), color='magenta', linestyle='dashed', alpha=0.1, linewidth=0.2, label='Posterior samples')
    plt.plot(x, stats.norm.pdf(x, np.mean(df.iloc[i]['mu']), np.mean(df.iloc[i]['sigma'])), color='magenta', linestyle='dashed', alpha=0.1, linewidth=0.2)
plt.ylabel('Probability density')
plt.legend()
plt.show()
